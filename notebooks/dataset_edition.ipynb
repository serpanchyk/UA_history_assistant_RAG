# %%
import pandas as pd
from src.config import settings

# %%
df = pd.read_parquet(settings.TEXTBOOKS_DF_PATH)

# %%
df.drop(4, axis=0, inplace=True)
df.head()
# Out:
#                                              pdf_name  \
# id
# 0            10-klas-istorija-ukrajiny-gisem-2018.pdf
# 1   Istoriia Ukrainy_pidruchnyk dlia 7 klasu ZZSO_...
# 2              Vstup-do-istorii-5-klas-Hisem-2022.pdf
# 3           11-klas-istoriya-ukr-vlasov-2024-prof.pdf
# 5           Istorija-Ukrajiny-8-klas-Halimov-2025.pdf
#
#                                                source
# id
# 0   Історія України (рівень стандарту) : підруч. д...
# 1   Історія України : підруч. для 7 класу закл. за...
# 2   Вступ до історії України та громадянської осві...
# 3   Історія України (профільний рівень) : підруч. ...
# 5   Історія України : підруч. для 8 класу закл. за...

# %%
df['id'] = range(len(df))

# %%
df.to_parquet(settings.TEXTBOOKS_DF_PATH, index=False)
