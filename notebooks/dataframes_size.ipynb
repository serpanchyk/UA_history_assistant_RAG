# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("../data/dfs/text_blocks.parquet")

df.head()
# Out:
#                                                 text  \
# 0                    УДК [37.016:94(477)](075.3) Г51
# 1  Рекомендовано Міністерством освіти і науки Укр...
# 2  Видано за рахунок державних коштів. Продаж заб...
# 3  Гісем О. В. Г51 Історія України (рівень станда...
# 4                        УДК [37.016:94(477)](075.3)
#
#                                                 bbox  page  doc_id
# 0  [73.70100402832031, 61.3690185546875, 214.3210...     1       0
# 1  [100.1719970703125, 121.24398803710938, 398.73...     1       0
# 2  [136.25099182128906, 150.72097778320312, 362.6...     1       0
# 3  [73.69699096679688, 352.01898193359375, 427.52...     1       0
# 4  [314.5790100097656, 417.760986328125, 425.2031...     1       0

# %%
df['text_length'] = df['text'].str.len()

# %%
df['text_length'].describe()
# Out:
# count    26096.000000
# mean       235.385538
# std        407.697462
# min          6.000000
# 25%         24.000000
# 50%         65.000000
# 75%        240.000000
# max       3647.000000
# Name: text_length, dtype: float64

# %%
df[["text_length"]].boxplot(figsize=(20,20))
plt.show()
